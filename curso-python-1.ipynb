# %% [markdown]
# Ejercicio 1. Python: Consola I, Variables I

# %% [markdown]
# Aprenderemos a crear variables, y también, a mostrar sus resultados en la consola, por el momento tan solo trabajaremos con números, a lo largo de este curso iremos trabajando con diferentes valores :D
#
# Recuerda, para seguir el código y todo, usa esta página para escribir y ejecutar sin descargar nada: https://replit.com/languages/python3

# %% [markdown]
# ¿Qué es una variable?
# --------------------------------
# Una variable es como una caja en el que podemos guardar y modificar cualquier dato/valor para poder usarla luego, pero eso sí, tan solo en el momento de ejecución, entonces, si sabes algo de ordenadores darás por hecho que se guarda en la RAM, con una explicación técnica es decirle a nuestro ordenador que nos asigne un espacio en la tarjeta RAM para guardar un rato
#
# Pero claro, ¿como creo mi variable en Python? Pues esto es especialmente fácil, aquí tenemos una imagen de como funciona nuestra estructura:

# %% [markdown]
# ![Captura desde 2022-05-27 16-38-48.png](attachment:6790463b-f0fc-4627-b4d2-7bdf0da94300.png)

# %% [markdown]
# Exactamente, de momento sería así para un número, vamos a probarlo

# %%
numero = 2

# %% [markdown]
# ¡Muy bien! Así se hace! :D

# %% [markdown]
# Manejando con la consola I | Mostrando valores
# ------------------------------------------------------------
#
# En Python, para mostrar algo en la consola necesitamos de una función, es una forma de llamar a una acción, pero, ¿Cómo se hace?, aquí tenemos una imagen:

# %% [markdown]
# ![nombre(1).png](attachment:dac399da-bbcd-4133-ab62-c22636b9ae37.png)

# %% [markdown]
# Bueno, pues aquí un ejemplo real:

# %%
print(1, 2, 3)

# %% [markdown]
# Bueno, mira que bien, ya has aprendido a guardar numeros, pero, como ponemos una variable en la función?

# %% [markdown]
# ![nombre(2).png](attachment:f9079b24-b1d8-47d5-a82d-8bcd689a2bee.png)

# %% [markdown]
# Muy bien, ahora con los conocimientos de programación en Python aprendidos, vamos a usarlos para hacer nuestro primer programa!

# %% [markdown]
# Ejercicio Final de hoy.
# --------------------------------------
#
# Bueno, pues nuestro programa de hoy, vamos a guardar un dato numérico en una variable y vamos a mostrarlo en la consola, bueno, comencemos!
#
# Creamos la variable:

# %%
variableNumerica = 5

# %% [markdown]
# Y ahora la mostramos:

# %%
print(variableNumerica)

# %% [markdown]
# Ahora, ya tienes un ejemplo, ahora te va a tocar hacerlo tu mismo, lo que harás es crear una variable que guarde tu edad, recuerda que puedes poner el nombre que quieras y luego mostrarla, pero recuerda, un truco muy bueno es que siempre que hagas una variable, intenta que su nombre concuerde con su dato, tipo, al crear la variable con tu edad, que se llame "edad" o "años" o algo asi
